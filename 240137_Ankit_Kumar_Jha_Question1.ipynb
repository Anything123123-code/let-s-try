# %% [markdown]
# <a href="https://colab.research.google.com/github/Anything123123-code/let-s-try/blob/main/240137_Ankit_Kumar_Jha_Question1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("/content/AAPL.csv")

# %%
df.head()
# Out:
#          Date    Open    High     Low   Close     Volume  Adj Close
# 0  03-01-2011  325.64  330.26  324.84  329.57  111284600      44.78
# 1  04-01-2011  332.44  332.50  328.15  331.29   77270200      45.01
# 2  05-01-2011  329.55  334.34  329.50  334.00   63879900      45.38
# 3  06-01-2011  334.72  335.25  332.90  333.73   75107200      45.34
# 4  07-01-2011  333.99  336.35  331.90  336.12   77982800      45.67

# %%
df=df.set_index("Date")

# %%
df["pct_change"]=df["Close"].pct_change()

# %%
df.head()
# Out:
#               Open    High     Low   Close     Volume  Adj Close  pct_change
# Date
# 03-01-2011  325.64  330.26  324.84  329.57  111284600      44.78         NaN
# 04-01-2011  332.44  332.50  328.15  331.29   77270200      45.01    0.005219
# 05-01-2011  329.55  334.34  329.50  334.00   63879900      45.38    0.008180
# 06-01-2011  334.72  335.25  332.90  333.73   75107200      45.34   -0.000808
# 07-01-2011  333.99  336.35  331.90  336.12   77982800      45.67    0.007161

# %%
df.isna().sum()
# Out:
# Open          0
# High          0
# Low           0
# Close         0
# Volume        0
# Adj Close     0
# pct_change    1
# dtype: int64

# %%
df=df.fillna(0)

# %%
df.head()
# Out:
#               Open    High     Low   Close     Volume  Adj Close  pct_change
# Date
# 03-01-2011  325.64  330.26  324.84  329.57  111284600      44.78    0.000000
# 04-01-2011  332.44  332.50  328.15  331.29   77270200      45.01    0.005219
# 05-01-2011  329.55  334.34  329.50  334.00   63879900      45.38    0.008180
# 06-01-2011  334.72  335.25  332.90  333.73   75107200      45.34   -0.000808
# 07-01-2011  333.99  336.35  331.90  336.12   77982800      45.67    0.007161

# %%
df['SMA_9'] = df['Close'].rolling(window=9).mean()
df['SMA_25'] =df['Close'].rolling(window=25).mean()
df['SMA_50'] =df['Close'].rolling(window=50).mean()

# %%
df['EMA_9'] = df['Close'].ewm(span=9,).mean()
df['EMA_25'] =df['Close'].ewm(span=25).mean()
df['EMA_50'] =df['Close'].ewm(span=50).mean()

# %%
df.head()
# Out:
#               Open    High     Low   Close     Volume  Adj Close  pct_change  \
# Date
# 03-01-2011  325.64  330.26  324.84  329.57  111284600      44.78    0.000000
# 04-01-2011  332.44  332.50  328.15  331.29   77270200      45.01    0.005219
# 05-01-2011  329.55  334.34  329.50  334.00   63879900      45.38    0.008180
# 06-01-2011  334.72  335.25  332.90  333.73   75107200      45.34   -0.000808
# 07-01-2011  333.99  336.35  331.90  336.12   77982800      45.67    0.007161
#
#             SMA_9  SMA_25  SMA_50       EMA_9      EMA_25      EMA_50
# Date
# 03-01-2011    NaN     NaN     NaN  329.570000  329.570000  329.570000
# 04-01-2011    NaN     NaN     NaN  330.525556  330.464400  330.447200
# 05-01-2011    NaN     NaN     NaN  331.949508  331.738422  331.679147
# 06-01-2011    NaN     NaN     NaN  332.552656  332.297591  332.223025
# 07-01-2011    NaN     NaN     NaN  333.613860  333.189073  333.065993
